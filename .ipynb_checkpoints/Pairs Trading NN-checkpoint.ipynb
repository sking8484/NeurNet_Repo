# %%
from NeuralNetwork import NeuralNetwork
import pandas as pd
from iexfinance.stocks import get_historical_data
import datetime as dt
import numpy as np

# %%
start = '01-01-2015'
end = dt.datetime.today()

# %%
overall_dataframe = pd.DataFrame(index = aal.index)

# %%
for stock in ['aal','dal','gld']:
    data = get_historical_data(stock, start, end, data_type ='pandas',token = 'pk_28978624c65e488392b272dbb54ae5ab',close_only = True)
    data = pd.DataFrame.from_dict(data,orient = 'index')[['close']]
    data['pct_change'] = data.pct_change()
    data = data[['pct_change']]
    data.columns = [stock]
    overall_dataframe = pd.concat([overall_dataframe,data],axis = 1)

# %%
overall_dataframe['next_change_aal'] = overall_dataframe['aal'].shift(-1)

# %%
def to_bool(data):
    if data >=0:
        return 1
    else:
        return -1

# %%
overall_dataframe['next_change_aal'] = overall_dataframe['next_change_aal'].map(to_bool)

# %%
overall_dataframe.dropna(inplace=True)

# %%
train_data = overall_dataframe.iloc[:-200]
test_data = overall_dataframe[-200:]

# %%
train_df_values = train_data.values

# %%
test_df_values = test_data.values

# %%
def vectorize(data):
    if data ==1:
        return [1,0]
    else:
        return [0,1]

# %%
def randomize():
    np.random.shuffle(train_df_values)
    train_inputs =[]
    train_answers =[]
    for x in train_df_values:
        train_inputs.append(x[:3])
        train_answers.append(vectorize(x[3]))
    return train_inputs,train_answers
test_inputs = []
test_answers = []
for x in test_df_values:
    test_inputs.append(x[:3])
    test_answers.append(vectorize(x[3]))

# %%
nn = NeuralNetwork(3,3,3,2,.1000)

# %%
# data = [
#     {'inputs':[0,0],'answer':[0]},
#     {'inputs':[0,1],'answer':[1]},
#     {'inputs':[1,0],'answer':[1]},
#     {'inputs':[1,1],'answer':[1]}
# ]

# %%
for epoch in range(100):
    print(epoch)
    train_inputs,train_answers = randomize()
    print(train_inputs[1])
    print(train_answers[1])
    for x in range(len(train_inputs)):
        nn.train(train_inputs[x],train_answers[x])
        

num_correct = 0
for x in range(len(test_inputs)):
    output = nn.feed_forward(test_inputs[x])
    print(output)
    output = np.argmax(output)
    answer = np.argmax(test_answers[x])
    
    if output == answer:
        num_correct+=1
print(num_correct/len(test_inputs))
# Out:
# 0
# [ 0.01201057 -0.00575303  0.0049776 ]
# [0, 1]
# 1
# [0.01500509 0.00169082 0.00182134]
# [1, 0]
# 2
# [-0.0328232  -0.01428299 -0.00211095]
# [1, 0]
# 3
# [-0.02882704 -0.02997394 -0.01265823]
# [1, 0]
# 4
# [0.00915798 0.0094598  0.00243046]
# [1, 0]
# 5
# [-0.01060709 -0.0056974   0.01040927]
# [0, 1]
# 6
# [ 0.00842146 -0.00053476  0.00461487]
# [0, 1]
# 7
# [ 0.00378931 -0.01147479  0.00509311]
# [1, 0]
# 8
# [ 0.00109242 -0.0060988  -0.008188  ]
# [0, 1]
# 9
# [0.01726533 0.00499445 0.00370402]
# [1, 0]
# 10
# [ 0.01211771 -0.00707547 -0.00561313]
# [1, 0]
# 11
# [ 0.00564392 -0.00022841  0.00349201]
# [1, 0]
# 12
# [ 0.0051474  -0.00107875 -0.00364299]
# [0, 1]
# 13
# [0.03804348 0.00711586 0.01448183]
# [1, 0]
# 14
# [-0.007281   -0.01312773 -0.00018669]
# [0, 1]
# 15
# [-0.03488372 -0.01432118 -0.00208684]
# [1, 0]
# 16
# [-0.00361098  0.01091157 -0.00363108]
# [1, 0]
# 17
# [0.02159777 0.00849437 0.01025068]
# [0, 1]
# 18
# [-0.00077061  0.00084818 -0.00611933]
# [0, 1]
# 19
# [-0.0168949  -0.00777523 -0.00063603]
# [0, 1]
# 20
# [ 0.02716298  0.04494863 -0.01777513]
# [0, 1]
# 21
# [ 0.01954545  0.01414921 -0.00097967]
# [0, 1]
# 22
# [-0.00550603  0.00597126 -0.00538475]
# [1, 0]
# 23
# [-0.00789936 -0.01904272 -0.00660066]
# [1, 0]
# 24
# [-0.00259373  0.01546961 -0.01488977]
# [1, 0]
# 25
# [0.00298686 0.00164474 0.00169688]
# [1, 0]
# 26
# [-0.00893313  0.0188465  -0.01037229]
# [1, 0]
# 27
# [-0.00090806  0.00253915  0.00555556]
# [1, 0]
# 28
# [-0.00979935 -0.00840657  0.00024089]
# [1, 0]
# 29
# [-0.02698062 -0.02836277  0.00345347]
# [0, 1]
# 30
# [-0.00778443 -0.00849057  0.00404124]
# [0, 1]
# 31
# [0.02178556 0.00639616 0.00364631]
# [0, 1]
# 32
# [-0.00261324 -0.00610565 -0.00086241]
# [1, 0]
# 33
# [-0.00165609  0.01274591  0.00198334]
# [1, 0]
# 34
# [ 0.00190996 -0.00815883 -0.00087067]
# [0, 1]
# 35
# [-0.0027248   0.00856327 -0.02053905]
# [1, 0]
# 36
# [-0.03228103 -0.04484398 -0.00462275]
# [1, 0]
# 37
# [ 0.01903743 -0.00059607 -0.00845921]
# [0, 1]
# 38
# [0.01935893 0.03365385 0.00073946]
# [1, 0]
# 39
# [-0.03443795 -0.03013145  0.01095013]
# [1, 0]
# 40
# [ 0.01346724  0.01508669 -0.00887478]
# [1, 0]
# 41
# [ 0.0408212   0.02546018 -0.00682594]
# [0, 1]
# 42
# [-0.00824588  0.00889218  0.00051827]
# [0, 1]
# 43
# [0.01347978 0.01040155 0.00296101]
# [0, 1]
# 44
# [ 0.00992496  0.0039929  -0.00367831]
# [1, 0]
# 45
# [-0.01407942 -0.01287705  0.00216693]
# [1, 0]
# 46
# [-0.03475162 -0.00881057 -0.00512776]
# [1, 0]
# 47
# [ 0.004313    0.00262763 -0.00393937]
# [1, 0]
# 48
# [0.00313643 0.00968921 0.00279256]
# [0, 1]
# 49
# [-0.02236682 -0.01159763  0.01223109]
# [0, 1]
# 50
# [-0.01600328 -0.03425197 -0.0033184 ]
# [1, 0]
# 51
# [-0.00556586 -0.00361991 -0.00057162]
# [1, 0]
# 52
# [-0.0066529   0.0014752   0.00146116]
# [1, 0]
# 53
# [0.0091417  0.02290076 0.00072405]
# [1, 0]
# 54
# [0.03215434 0.01093374 0.00575314]
# [1, 0]
# 55
# [-0.01609195 -0.0191681  -0.00763209]
# [0, 1]
# 56
# [-0.00695803  0.00373942 -0.00170114]
# [1, 0]
# 57
# [-0.00055804 -0.00509814 -0.0011884 ]
# [1, 0]
# 58
# [-0.00987654 -0.02304806 -0.00015958]
# [0, 1]
# 59
# [-0.00608221 -0.01248761  0.01202636]
# [1, 0]
# 60
# [ 0.00768322 -0.00763494 -0.00118967]
# [1, 0]
# 61
# [ 0.03951976  0.01547763 -0.0017343 ]
# [1, 0]
# 62
# [0.0131951  0.00905588 0.00016055]
# [0, 1]
# 63
# [-0.00838037 -0.00802273  0.00165406]
# [1, 0]
# 64
# [-0.04498064 -0.02154696  0.00112272]
# [0, 1]
# 65
# [0.01462664 0.01171221 0.0029399 ]
# [0, 1]
# 66
# [-0.00433071  0.00276625 -0.00117008]
# [0, 1]
# 67
# [-0.01635846  0.00673328  0.00249066]
# [1, 0]
# 68
# [0.04908888 0.04761905 0.00327921]
# [1, 0]
# 69
# [0.00630493 0.         0.00512738]
# [0, 1]
# 70
# [ 0.         -0.00311345  0.01125442]
# [1, 0]
# 71
# [-0.05323654 -0.02357564  0.00203073]
# [0, 1]
# 72
# [0.02176871 0.02749519 0.00601202]
# [1, 0]
# 73
# [ 0.0038674   0.0212766  -0.00288995]
# [0, 1]
# 74
# [ 0.01035822  0.00060963 -0.00565121]
# [0, 1]
# 75
# [-0.00328638 -0.01531191 -0.00408   ]
# [1, 0]
# 76
# [-0.03525741 -0.00880282  0.00605366]
# [1, 0]
# 77
# [0.00680553 0.01325353 0.00540541]
# [0, 1]
# 78
# [-0.00894152 -0.01317657  0.00461144]
# [0, 1]
# 79
# [ 0.01359966 -0.0030947   0.01046738]
# [0, 1]
# 80
# [-0.00642099 -0.01388147  0.        ]
# [1, 0]
# 81
# [ 0.03079619  0.00936719 -0.01397659]
# [0, 1]
# 82
# [-0.02400582 -0.01459541  0.02097579]
# [0, 1]
# 83
# [0.02202166 0.00524283 0.00500636]
# [1, 0]
# 84
# [ 0.03079619  0.00936719 -0.01397659]
# [0, 1]
# 85
# [-0.0156852  -0.01670977  0.00048119]
# [1, 0]
# 86
# [ 0.04761905  0.02143446 -0.00599572]
# [1, 0]
# 87
# [ 0.01913754  0.03023804 -0.01066222]
# [1, 0]
# 88
# [ 0.01028504  0.0055068  -0.00190856]
# [0, 1]
# 89
# [0.028402   0.00125549 0.0034585 ]
# [0, 1]
# 90
# [ 0.00064558  0.00591716 -0.01482641]
# [0, 1]
# 91
# [-0.00140885  0.02175687  0.002079  ]
# [0, 1]
# 92
# [0.00372787 0.00457457 0.00154233]
# [0, 1]
# 93
# [-0.01679053 -0.00124733 -0.00240034]
# [0, 1]
# 94
# [0.03188124 0.03002402 0.01087809]
# [1, 0]
# 95
